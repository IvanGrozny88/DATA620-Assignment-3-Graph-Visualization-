# %% [markdown]
# DATA620 Assignment 3: Graph Visualization
# IvanTikhonov
# This week's assignment is to:
# 1. Load a graph database of your choosing from a text file or other source. If you take a
# large network dataset from the web (such as from https://snap.stanford.edu/data/), please
# feel free at this point to load just a small subset of the nodes and edges.
# 2. Create basic analysis on the graph, including the graph’s diameter, and at least one other
# metric of your choosing. You may either code the functions by hand (to build your
# intuition and insight), or use functions in an existing package.
# 3. Use a visualization tool of your choice (Neo4j, Gephi, etc.) to display information.
# 4. Please record a short video (~ 5 minutes), and submit a link to the video as part of your
# homework submission.
# Data source
# https://snap.stanford.edu/data/facebook_combined.txt.gz
#
# Laod the libraries

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# Set the parameters
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4

# %% [markdown]
# Read the facebook data

# %%
# Read 500 rows
dt = pd.read_table("C:/Users/Ivant/Desktop/facebook_combined (2).txt/facebook_combined.txt", sep = " ", names = ['source','target'])

# %%
dt = dt[300:400]

# %%
dt.head()
# Out:
#      source  target
# 300       0     301
# 301       0     302
# 302       0     303
# 303       0     304
# 304       0     305

# %%
dt.shape
# Out:
# (100, 2)

# %% [markdown]
# Make a graph object

# %%
G = nx.from_pandas_edgelist(dt)

# %%
print( nx.info(G))
# Out:
# Graph with 94 nodes and 100 edges
# C:\Users\Ivant\AppData\Local\Temp\ipykernel_6676\379776619.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print( nx.info(G))

# %% [markdown]
# The graph has 94 nodes, 100 edges

# %% [markdown]
# Diameter

# %%
nx.algorithms.diameter(G)
# Out:
# 8

# %% [markdown]
# The diameter of the graph is 8.

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
nx.draw(G, node_color='green', with_labels=True)

# %%
plt.savefig("facebook user network graph.png")
